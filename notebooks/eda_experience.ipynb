# %%
import sys
import os

sys.path.append(os.path.abspath("../"))

from src.data.data_loading import load_cleaned_dataset

# Load the cleaned dataset
df = load_cleaned_dataset()

# Display the first few rows
print(df.head())
# Out:
#       bearer_id                start  start_ms                  end  end_ms  \
# 0  1.311448e+19  2019-04-04 12:01:00     770.0  2019-04-25 14:35:00   662.0
# 1  1.311448e+19  2019-04-09 13:04:00     235.0  2019-04-25 08:15:00   606.0
# 2  1.311448e+19  2019-04-09 17:42:00      10.0  2019-04-25 11:58:00   652.0
# 3  1.311448e+19  2019-04-10 00:31:00     486.0  2019-04-25 07:36:00   171.0
# 4  1.311448e+19  2019-04-12 20:10:00     565.0  2019-04-25 10:40:00   954.0
#
#    dur._(ms)          imsi  msisdn/number          imei  \
# 0   398786.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1   398786.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2   398786.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3   398786.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4   398786.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       last_location_name  ...  netflix_dl_(bytes)  netflix_ul_(bytes)  \
# 0  9.16456699548519E+015  ...           8198936.0           9656251.0
# ...

# %% [markdown]
# #### Import Necessary Modules

# %%
from src.analysis.experience_analysis import (
    aggregate_experience_metrics,
    top_bottom_frequent_values,
    plot_throughput_distribution_by_handset,
    plot_tcp_retransmission_by_handset,
    cluster_users_by_experience,
    describe_clusters,
    perform_experience_analysis
)

# %%
# Perform complete experience analysis
results = perform_experience_analysis(df)

# %% [markdown]
# #### Aggregate Experience Metrics

# %%
print("Aggregated Metrics:")
print(results["aggregated_metrics"].head())
# Out:
# Aggregated Metrics:
#    msisdn/number  avg_tcp_retransmission     avg_rtt  avg_throughput  \
# 0   3.360388e+10            1.510419e+07   84.807119     9360.563624
# 1   3.360389e+10            2.080991e+07  353.000000       50.000000
# 2   3.360389e+10            2.080991e+07  109.795706        6.000000
# 3   3.360389e+10            2.080991e+07   42.500000      233.000000
# 4   3.360389e+10            2.080991e+07  109.795706       48.000000
#
#                  handset_type  experience_cluster
# 0  Samsung Galaxy A5 Sm-A520F                   0
# 1      Apple iPhone 6 (A1586)                   0
# 2  Samsung Galaxy A5 Sm-A520F                   0
# 3      Apple iPhone 6 (A1586)                   0
# 4                   undefined                   0

# %% [markdown]
# #### TCP Analysis

# %%
print("\nTCP Analysis (Top 10):")
print(results["tcp_analysis"]["top"])
# Out:
# TCP Analysis (Top 10):
#       avg_tcp_retransmission
# 15                90901514.0
# 227               90901514.0
# 1195              90901514.0
# 2411              90901514.0
# 5454              90901514.0
# 7917              90901514.0
# 8076              90901514.0
# 8387              90901514.0
# 8599              90901514.0
# 9730              90901514.0

# %% [markdown]
# #### RTT Analysis

# %%
print("\nRTT Analysis (Top 10):")
print(results["rtt_analysis"]["top"])
# Out:
# RTT Analysis (Top 10):
#      avg_rtt
# 17    1010.0
# 48    1010.0
# 227   1010.0
# 253   1010.0
# 387   1010.0
# 411   1010.0
# 446   1010.0
# 459   1010.0
# 513   1010.0
# 603   1010.0

# %% [markdown]
# #### Throughput Analysis

# %%
print("\nThroughput Analysis (Top 10):")
print(results["throughput_analysis"]["top"])
# Out:
# Throughput Analysis (Top 10):
#       avg_throughput
# 461         103160.0
# 560         103160.0
# 877         103160.0
# 1414        103160.0
# 1915        103160.0
# 2034        103160.0
# 2263        103160.0
# 2548        103160.0
# 2563        103160.0
# 3426        103160.0

# %% [markdown]
# #### Cluster Summary

# %%
print("\nThroughput Analysis (Top 10):")
print(results["throughput_analysis"]["top"])
# Out:
# Throughput Analysis (Top 10):
#       avg_throughput
# 461         103160.0
# 560         103160.0
# 877         103160.0
# 1414        103160.0
# 1915        103160.0
# 2034        103160.0
# 2263        103160.0
# 2548        103160.0
# 2563        103160.0
# 3426        103160.0

# %% [markdown]
# ####
